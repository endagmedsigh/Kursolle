# %%
#m05u01
def info():
    print("Sami Mounir TE19D NTI kronhus")

info()
# Out:
# Sami Mounir TE19D NTI kronhus

# %%
#m05u02 och #m05u03
import math

def area(r):
    c = r*r*math.pi 
    print(f"Arean är: {c}")

def omkrets():
    global r
    c = r*2*math.pi
    print(f"Omkretsen är: {c}")


r = int(input("Välj din radie"))
print(f"Radien du valde: {r}")

area(r)
omkrets()
# Out:
# Radien du valde: 4
# Arean är: 50.26548245743669
# Omkretsen är: 25.132741228718345

# %%
#m05u05 och m05u06

from functions import area as a
from functions import omkrets as o

r = int(input("Välj din radie"))
print(f"Radien du valde: {r}")

a(r)
o()
# Out:
# Radien du valde: 5
# Arean är: 78.53981633974483
# Omkretsen är: 18.84955592153876

# %%
#m05u07 + extra uppgift

from m05u07_funktioner import *
 
julgran(10)
tomten()
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# Ho,Ho,Ho!
# Jullovet är nära

# %%
#m05u08

datatyp = []
ex_datatyp = []
info_datatyp = []

with open("datatyper.txt") as f:
    for rad in f:
        rad = rad.split("|")


        datatyp.append(rad[0].lstrip())
        ex_datatyp.append(rad[1].lstrip())
        info_datatyp.append(rad[2].lstrip())

for i, t in enumerate(datatyp):
    print('{:<15}{}\n{:<15}{}\n{:<15}{}'.format('Datatyp:', t, 'Exempel:', ex_datatyp[i], 'Förklaring:', info_datatyp[i]))
# Out:
# Datatyp:       string
# Exempel:       "@", "Johan", 'Sebastian'
# Förklaring:    Alla texter och tecken. Markeras med dubbelfnutt(") eller enkelfnutt(')
#
# Datatyp:       int
# Exempel:       1, 7, -9
# Förklaring:    StÃ¥r fÃ¶r integer och lagrar heltal
#
# Datatyp:       float
# Exempel:       0.0, 4.5, -9.7
# Förklaring:    Flyttal, lagrar decimaltal, notera decimalpunkt enligt engelsksprÃ¥kig standard
#
# Datatyp:       boolean
# Exempel:       True, False
# Förklaring:    Boolesk variabel, lagrar sant eller falskt, ofta ett resultat av ett uttryck som (1 < 2)

# %%
#m05u08

lista = []


with open("provpoäng.txt") as f1:
    for rad in f1:
        rad = rad.strip()
        lista.append(int(rad))

sortedlista = sorted(lista)

for rad in sortedlista:
    print(rad)

längden = len(lista)

print(f"\nDet finns {längden} i provpoäng filen")

summan = sum(lista)
medel = summan//längden

print(f"Medelvärdet blir {medel} avrundad")
# Out:
# 5
# 6
# 11
# 15
# 22
# 22
# 24
# 24
# 25
# 26
# 28
# 34
# 61
# 63
# 67
# 68
# 71
# 82
# 89
# 89
# 90
# 90
# 90
# 93
# 94
#
# Det finns 25 i provpoäng filen
# Medelvärdet blir 51 avrundad

# %%
#m05u09

lista =[]
flista = []
elista = []
dlista = []
clista = []
blista = []
alista = []
värdet = []

alla = ["F","E","D","C","B","A"]
with open("provpoäng1.txt","r") as f1:
    for rad in f1:
        rad = rad.strip("\n")
        lista.append(rad)


        sak= int(rad[-2:])

        värdet.append(int(rad[-2:]))

        summan = sum(värdet)

        längden = len(lista)

        if sak < 20:
            flista.append(rad)

        elif 29 >= sak >= 20:
            elista.append(rad)
            
        elif 39 >= sak >= 30:
            dlista.append(rad)
            
        elif 49 >= sak >= 40:
            clista.append(rad)

        elif 59 >= sak >= 50:
            blista.append(rad)

        elif 70 >= sak >= 60:
            alista.append(rad)
    

    print("\nF")
    for människa in flista:
        print(människa)
    
    print("\nE")
    for människa in elista:
        print(människa)
        
    print("\nD")
    for människa in dlista:
        print(människa)
    
    print("\nC")
    for människa in clista:
        print(människa)
    
    print("\nB")
    for människa in blista:
        print(människa)
    
    print("\nA")
    for människa in alista:
        print(människa)

medelvärdet = summan//längden
print(f"\nMedelvärdet av detta är {medelvärdet} avrundad")
# Out:
# F
# Noomi| 5
# Henry|19
# Bertil| 9
#
# E
# Franz|28
# Mila|24
# Cilla|25
# Liridon|24
# Susan|20
# Nicholas|22
#
# D
# Walter|36
#
# C
# Theodor|40
# Henry|46
#
# B
# Omar|58
# Katarina|57
#
# A
# Bianca|66
# Leia|63
#
# Medelvärdet av detta är 51 avrundad

# %%
#m05u11

saldo = startsaldo = 1000
ränta = 1.03
txt = "pengarfil.txt"

with open(txt,"w") as f:
    for år in range (1,16):
        saldo *= ränta
        f.write(f"{år} {saldo:.0f} {((saldo/startsaldo)-1)*100:5.2f}%\n" )

with open(txt) as f:
    print(f.read())
# Out:
# 1 1030  3.00%
# 2 1061  6.09%
# 3 1093  9.27%
# 4 1126 12.55%
# 5 1159 15.93%
# 6 1194 19.41%
# 7 1230 22.99%
# 8 1267 26.68%
# 9 1305 30.48%
# 10 1344 34.39%
# 11 1384 38.42%
# 12 1426 42.58%
# 13 1469 46.85%
# 14 1513 51.26%
# 15 1558 55.80%

# %%
#m05u12

from functions2 import*

f =open(filnamn,"w")
f.close()


with open(filnamn, "a") as f:
    while True:
        inmatning = int(input("Skriv ett heltal programmet stängs av om du trycker 0"))
        if inmatning == 0:
            f.write("\nDu tryckte på 0, Nuclear weapong will deploy")
            break

        lista.append(inmatning)
        f.write(f"Talet du tryckte {inmatning}, min: {minsta()}, max: {största()}, summa: {summa()}." )


print("\n\nVad filen innehåller")
with open(filnamn) as f:
    print(f.read())
# Out:
# Vad filen innehåller
# Talet du tryckte 6, min: 2, max: 6, summa: 116.
# Du tryckte på 0, Nuclear weapong will deploy

# %%
#m05u13

import pprint
pp = pprint.PrettyPrinter(indent=2)


lista = []
with open('lagring2.txt') as f:
    for rad in f:
        rad = rad.strip()
        rad = rad.split('|')
        d = {'name':rad[0], 'points': int(rad[1])}
        lista.append(d)






d_min = d_max = lista[0]
summa = 0





for l in lista:
    summa += l['points']
    if l['points'] > d_max['points']:
        d_max = l
    if l['points'] < d_min['points']:
        d_min = l
    
l_sorted = sorted(lista, key=lambda i: i['points'], reverse=True)



with open("m05u13_output.txt", "w") as fw:
    fw.write("Sorterad resultatlista, högsta poäng överst. \n")
    for l in lista:
        fw.write(f"{l['points']:2d} | {l['name']}\n")
    
    fw.write(f"\n## Summering ##\nHögsta resultat: {d_max['name']}, {d_max['points']} poäng."
            f"\nLägsta resultat: {d_min['name']}, {d_min['points']} poäng." 
            f"\nMedelpoäng: {summa/len(lista):.2f}")



with open("lagring2.txt") as f:
    print(f.read())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-848f312430d4> in <module>
#      18
#      19
# ---> 20 d_min = d_max = lista[0]
#      21 summa = 0
#      22
#
# IndexError: list index out of range
